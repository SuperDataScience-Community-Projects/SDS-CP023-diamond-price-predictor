# %% [markdown]
# # **SDS-CP023-Diamond Price Prediction**

# %% [markdown]
# ## **Problem Definition**
#
# ### **The Context:**
#
#  - Why is this problem important to solve?
# To build a model that will predict the price of diamond based on the following features/attributes - carat, cut, color, clarity, depth, and dimensions.
#
# ### **The objective:**
#
#  - What is the intended goal?
# To predict price that matches the actual price 95% of the time.
#
# ### **The key questions:**
#
# - What are the key questions that need to be answered?
# 1.
# 2.

# %% [markdown]
# ## **Data Description:**
#
#
#
# * **Price:** cost of diamond in US dollars $
#
# * **carat:** weight of the diamond
#
# * **cut:** represents the 'shine' with the following categories: ideal, premium, good, very good and fair
#
# * **color:** the color is for visual appeal. Values range from D to J.
#
# * **clarity:** explains the internal diamond purity with these classifications - SI2 SI1 VS1 VS2 VVS2 VVS1 and I1.
#
# * **depth:** represents the diamond depth percentage
#
# * **table:** measure of flatness at the top
#
# * **dimensions:** different measurements from the flat surface - x = width, y = length, z = height

# %% [markdown]
# ### **Import the necessary libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import(
 LabelEncoder,
 OneHotEncoder,
 OrdinalEncoder)
from sklearn.model_selection import train_test_split #for Linear and Logistic Regression modeling

# %% [markdown]
# ### **Read the dataset**

# %%
diamdata=pd.read_csv("C:/Users/adann/Desktop/gitDocuments/sds_diamond_beginner_project/type of the Diamond new.csv")

# %%
# Copying data to another variable to avoid any changes to original data
data=diamdata.copy()

# %% [markdown]
# ### **Print the first and last 5 rows of the dataset**

# %%
# Display first five rows

data.head()
# Out:
#     cut color clarity  carat  depth  table  price  x (Premium)  z (Very Good)  \
# 0  Fair     E     VS2   0.22   65.1   61.0    337         3.87           2.49
# 1  Fair     E     SI2   0.86   55.1   69.0   2757         6.45           3.52
# 2  Fair     F     SI2   0.96   66.3   62.0   2759         6.27           4.07
# 3  Fair     F     VS2   0.70   64.5   57.0   2762         5.57           3.58
# 4  Fair     F     VS2   0.70   65.3   55.0   2762         5.63           3.66
#
#    y (Good)
# 0      3.78
# 1      6.33
# 2      5.95
# 3      5.53
# 4      5.58

# %%
#rename x, z, y columns
data.rename(columns={'x (Premium)':'x_(Premium)', 'z (Very Good)':'z_(Very Good)', 'y (Good)':'y_(Good)'}, inplace = True)

# %%
#Reorder the columns..
data = data[['cut', 'color', 'clarity', 'carat', 'depth', 'table', 'x_(Premium)', 'z_(Very Good)', 'y_(Good)', 'price',]]

# %%
# re-print the first five rows

data.head()
# Out:
#     cut color clarity  carat  depth  table  x_(Premium)  z_(Very Good)  \
# 0  Fair     E     VS2   0.22   65.1   61.0         3.87           2.49
# 1  Fair     E     SI2   0.86   55.1   69.0         6.45           3.52
# 2  Fair     F     SI2   0.96   66.3   62.0         6.27           4.07
# 3  Fair     F     VS2   0.70   64.5   57.0         5.57           3.58
# 4  Fair     F     VS2   0.70   65.3   55.0         5.63           3.66
#
#    y_(Good)  price
# 0      3.78    337
# 1      6.33   2757
# 2      5.95   2759
# 3      5.53   2762
# 4      5.58   2762

# %%
# Display last 5 rows
data.tail()
# Out:
#              cut color clarity  carat  depth  table  x_(Premium)  \
# 53935  Very Good     E     VS2    0.7   62.8   60.0         5.59
# 53936  Very Good     D     VS1    0.7   63.1   59.0         5.67
# 53937  Very Good     E     VS2    0.7   60.5   59.0         5.71
# 53938  Very Good     E     VS2    0.7   61.2   59.0         5.69
# 53939  Very Good     D     SI1    0.7   62.8   60.0         5.66
#
#        z_(Very Good)  y_(Good)  price
# 53935           3.53      5.65   2755
# 53936           3.55      5.58   2755
# 53937           3.47      5.76   2757
# 53938           3.49      5.72   2757
# 53939           3.56      5.68   2757

# %% [markdown]
# ### **Understand the shape of the dataset**

# %%
# Check the shape of the data

data.shape
# Out:
# (53940, 10)

# %% [markdown]
# **Insights __::**
# - The data contains **53,940 observations and 10 columns**.

# %% [markdown]
# ### **Check the data types of the columns**

# %%
# Check info of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cut            53940 non-null  object
#  1   color          53940 non-null  object
#  2   clarity        53940 non-null  object
#  3   carat          53940 non-null  float64
#  4   depth          53940 non-null  float64
#  5   table          53940 non-null  float64
#  6   x_(Premium)    53940 non-null  float64
#  7   z_(Very Good)  53940 non-null  float64
#  8   y_(Good)       53940 non-null  float64
#  9   price          53940 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# **Insights ______________**
# - There are no missing values for any of the observations and columns.
# - There are only three categorical variables, the rest are numerical.

# %% [markdown]
# ### **Check for missing values**

# %%
# Analyse missing values - Hint: use isnull() function
data.isnull().sum()
# Out:
# cut              0
# color            0
# clarity          0
# carat            0
# depth            0
# table            0
# price            0
# x (Premium)      0
# z (Very Good)    0
# y (Good)         0
# dtype: int64

# %%
# Check the percentage of missing values in the each column.
# Hint: divide the result from the previous code by the number of rows in the dataset

data.isnull().sum()/data.shape[0]
# Out:
# cut              0.0
# color            0.0
# clarity          0.0
# carat            0.0
# depth            0.0
# table            0.0
# price            0.0
# x (Premium)      0.0
# z (Very Good)    0.0
# y (Good)         0.0
# dtype: float64

# %% [markdown]
# **The percentage of missing values is 0% for all variables/columns.**

# %% [markdown]
# **We can convert the object type columns to categories**
#
# `converting "objects" to "category" reduces the data space required to store the dataframe`

# %% [markdown]
# ### **Convert the data types???**

# %%
cols = data.select_dtypes(['object']).columns.tolist()

#adding target variable to this list as this is an classification problem and the target variable is categorical

# %%
cols
# Out:
# ['cut', 'color', 'clarity']

# %%
# Changing the data type of object type column to category. hint use astype() function

for i in cols:
    data[i] = data[i].astype("category")

# %%
# Checking the info again and the datatype of different variable

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cut            53940 non-null  category
#  1   color          53940 non-null  category
#  2   clarity        53940 non-null  category
#  3   carat          53940 non-null  float64
#  4   depth          53940 non-null  float64
#  5   table          53940 non-null  float64
#  6   price          53940 non-null  int64
#  7   x (Premium)    53940 non-null  float64
#  8   z (Very Good)  53940 non-null  float64
#  9   y (Good)       53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
Q1= np.percentile(data["price"], 25)
print(Q1)
# Out:
# 950.0

# %% [markdown]
# ### **Analyze Summary Statistics of the dataset**

# %%
# Analyze the summary statistics for numerical variables

data.describe(include = 'number').T
# Out:
#                  count         mean          std    min     25%      50%  \
# carat          53940.0     0.797940     0.474011    0.2    0.40     0.70
# depth          53940.0    61.749405     1.432621   43.0   61.00    61.80
# table          53940.0    57.457184     2.234491   43.0   56.00    57.00
# price          53940.0  3932.799722  3989.439738  326.0  950.00  2401.00
# x (Premium)    53940.0     5.731157     1.121761    0.0    4.71     5.70
# z (Very Good)  53940.0     3.538734     0.705699    0.0    2.91     3.53
# y (Good)       53940.0     5.734526     1.142135    0.0    4.72     5.71
#
#                    75%       max
# carat             1.04      5.01
# depth            62.50     79.00
# table            59.00     95.00
# price          5324.25  18823.00
# x (Premium)       6.54     10.74
# z (Very Good)     4.04     31.80
# y (Good)          6.54     58.90

# %%
#Categorize the features by type:
numerical_features = ['carat', 'depth', 'table', 'price', 'x_(Premium)', 'z_(Very Good)', 'y_(Good)']
categorical_features = ['cut', 'color', 'clarity']

# %% [markdown]
# **Observations**
#
# - Average carat is .798, maximum is 5.01. Minimum is 0.2.
# - For the depth, the average is 61.7, max is 79 with a std dev of 1.43.
# - The table measurements are close, ranging from minimum of 43 to max of 95. Average is 57.
# - Price is the target dependent variable we need to predict. It has a high standard deviation indicating high variance meaning a lot of the diamond rings are highly expensive. Minimum price is 326, ranging up to a maximum of 18000. 50% of the diamonds cost $2,400.
# - Max or oldest CLAGE is 1168. Average age is 175 while std dev is 85.
#  - For the dimension, the Premium (x = width) has the lowest maximum among the 3 dimensions.

# %%
# Check summary for categorical data.

#data.describe(include = "category").T

# %% [markdown]
# **Insights**
#
# - This table lists the hightest categories among the categorical variables.
# - The hightest cut/shine is the "Ideal" option.
# - The predominant color is "G".
# - The highest clarity, indicating diamond purity is Sl1.

# %% [markdown]
# **Let's look at the unique values in all the categorical variables**

# %%
# Checking the count of unique values in each categorical column 

cols_cat= data.select_dtypes(['category'])

for i in cols_cat.columns:
    print('Unique values in',i, 'are :')
    print(data[i].nunique(dropna = False))
    print('*'*40)
# Out:
# Unique values in cut are :
# 5
# ****************************************
# Unique values in color are :
# 7
# ****************************************
# Unique values in clarity are :
# 8
# ****************************************

# %% [markdown]
# ### **Think about it**
# - The results above gave the absolute count of unique values in each categorical column. Are absolute values a good measure?
# - If not, what else can be used? Try implementing that.

# %%
#To print the actual unique values..

cols_cat= data.select_dtypes(['category'])

for i in cols_cat.columns:
    print('Unique values in',i, 'are :')
    print(data[i].value_counts(dropna = False))
    print('*'*40)
# Out:
# Unique values in cut are :
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64
# ****************************************
# Unique values in color are :
# color
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64
# ****************************************
# Unique values in clarity are :
# clarity
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: count, dtype: int64
# ****************************************

# %% [markdown]
# **Insights**
# - Printing the unique values in each category reveals there is noblank values "NaN".
# - There is no need to replace any blank value with median if distribution is skewed or with mean if normal distribution.

# %%
#To print the actual % of unique values..

cols_cat= data.select_dtypes(['category'])

for i in cols_cat.columns:
    print('Unique values in',i, 'are :')
    print(data[i].value_counts(dropna = False))
    print('Percentag of unique values in',i, 'are :')
    print(data[i].value_counts(dropna = False)/data[i].shape[0])
    print('*'*40)
# Out:
# Unique values in cut are :
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64
# Percentag of unique values in cut are :
# cut
# Ideal        0.399537
# Premium      0.255673
# Very Good    0.223990
# Good         0.090953
# Fair         0.029848
# Name: count, dtype: float64
# ****************************************
# Unique values in color are :
# color
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64
# Percentag of unique values in color are :
# color
# G    0.209344
# E    0.181628
# F    0.176900
# H    0.153949
# D    0.125603
# I    0.100519
# J    0.052058
# Name: count, dtype: float64
# ****************************************
# Unique values in clarity are :
# clarity
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: count, dtype: int64
# Percentag of unique values in clarity are :
# clarity
# SI1     0.242214
# VS2     0.227253
# SI2     0.170449
# VS1     0.151483
# VVS2    0.093919
# VVS1    0.067760
# IF      0.033185
# I1      0.013737
# Name: count, dtype: float64
# ****************************************

# %% [markdown]
# ## **Exploratory Data Analysis (EDA) and Visualization**

# %% [markdown]
# ## **Univariate Analysis**
#
# Univariate analysis is used to explore each variable in a data set, separately. It looks at the range of values, as well as the central tendency of the values. It can be done for both numerical and categorical variables

# %% [markdown]
# ### **1. Univariate Analysis - Numerical Data**
# Histograms and box plots help to visualize and describe numerical data. We use box plot and histogram to analyze the numerical columns.

# %%
#plt.figure(figsize=(15, 10))
for i, feature in enumerate(numerical_features): #[:6], 1):
    plt.subplot(121)
    sns.boxplot(x = data[feature], showmeans=True, color='violet') # boxplot will be created and a star will indicate the mean value of the column
    plt.subplot(122)
    sns.histplot(x = data[feature], kde=False, color="blue") #, gridspec_kw = {"height_ratios": (.25, .75)}) if bins else sns.histplot(x = data['carat'], kde=False) # For histogram
#    plt.title(f'{feature} Distribution') #palette="winter"
#plt.tight_layout()
plt.show()
#ax_hist2.axvline(np.mean(feature), color='green', linestyle='--') # Add mean to the histogram
   # ax_hist2.axvline(np.median(feature), color='black', linestyle='-') # Add median to the histogram

# %% [markdown]
# #### Using the above function, let's first analyze the Histogram and Boxplot for PRICE

# %%
plt.figure(figsize=(10, 5))
plt.subplot(121)
sns.boxplot(x = data['price'], showmeans=True, color='violet') # boxplot will be created and a star will indicate the mean value of the column
plt.subplot(122)
sns.histplot(x = data['price'], kde=False, color="blue") #, gridspec_kw = {"height_ratios": (.25, .75)}) if bins else sns.histplot(x = data['carat'], kde=False) # For histogram
#    plt.title(f'{feature} Distribution') #palette="winter"
#plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
# - Average price is ~3900. Based on the 25% and 75% IQR indicates that half the people/50% of the price paid is between $1000 - 5000. The outliers are greater than $10,000. The distribution is left-skewed showing that the price of most rings bought are 5000 or less.

# %% [markdown]
# #### **Note:** As done above, analyze Histogram and Boxplot for other variables

# %%
# Build the histogram boxplot for carat
plt.figure(figsize=(10, 5))
plt.subplot(121)
sns.boxplot(x = data['carat'], showmeans=True, color='violet') # boxplot will be created and a star will indicate the mean value of the column
plt.subplot(122)
sns.histplot(x = data['carat'], kde=False, color="blue") #, gridspec_kw = {"height_ratios": (.25, .75)}) if bins else sns.histplot(x = data['carat'], kde=False) # For histogram
#    plt.title(f'{feature} Distribution') #palette="winter"
#plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
# - The average carat made/bought is less than 1 carat and is higher than the median of .7.

# %%
# Build the histogram boxplot for VALUE
plt.figure(figsize=(10, 5))
plt.subplot(121)
sns.boxplot(x = data['depth'], showmeans=True, color='violet') # boxplot will be created and a star will indicate the mean value of the column
plt.subplot(122)
sns.histplot(x = data['depth'], kde=False, color="blue") #, gridspec_kw = {"height_ratios": (.25, .75)}) if bins else sns.histplot(x = data['carat'], kde=False) # For histogram
#    plt.title(f'{feature} Distribution') #palette="winter"
#plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
# - The depthn follows a normal distribution.
# - The median and mean seem equal.

# %%
# Build the histogram boxplot for YOJ
plt.figure(figsize=(10, 5))
plt.subplot(121)
sns.boxplot(x = data['table'], showmeans=True, color='violet') # boxplot will be created and a star will indicate the mean value of the column
plt.subplot(122)
sns.histplot(x = data['table'], kde=False, color="blue") #, gridspec_kw = {"height_ratios": (.25, .75)}) if bins else sns.histplot(x = data['carat'], kde=False) # For histogram
#    plt.title(f'{feature} Distribution') #palette="winter"
#plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations**
# - The table follows a normal spread as well but slightly left-skewed.loyed) varies from 0 to 38 years.

# %% [markdown]
# ### **2. Univariate Analysis - Categorical Data**

# %% [markdown]
# #### Analyze Barplot for DELINQ

# %%
#Build barplot for DELINQ

plt.figure(figsize=(15,5))
ax = sns.countplot(x=data["cut"],palette='winter')
#perc_on_bar(ax,data["cut"])
for container in ax.containers:
    ax.bar_label(container)
# Out:
# C:\Users\adann\AppData\Local\Temp\ipykernel_17716\3676286955.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=data["cut"],palette='winter')

# %% [markdown]
# **Insights**
# - 40% of the cuts are the Ideal brand, followed by Premium.

# %% [markdown]
# #### **Note:** As done above, analyze Histogram and Boxplot for other variables.

# %%
#Build barplot for NINQ #CLAGE did not display correctly

plt.figure(figsize=(15,5))
ax = sns.countplot(x=data["color"],palette='winter')
for container in ax.containers:
    ax.bar_label(container)
# Out:
# C:\Users\adann\AppData\Local\Temp\ipykernel_17716\3538385892.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=data["color"],palette='winter')

# %% [markdown]
# **Insights**
# - The preferred color based on the distribution is color G.
# - This is followed by color E then F.

# %%
#Build barplot for CLNO

plt.figure(figsize=(15,5))
ax = sns.countplot(x=data["clarity"],palette='winter')
for container in ax.containers:
    ax.bar_label(container)
# Out:
# C:\Users\adann\AppData\Local\Temp\ipykernel_17716\3489206348.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=data["clarity"],palette='winter')

# %% [markdown]
# **Insights**
# - Sl1 and VS2 are the most sold purity level.

# %% [markdown]
# ## **Bivariate Analysis**

# %% [markdown]
# ### **Bivariate Analysis: Continuous and Categorical Variables**

# %% [markdown]
# #### Analyze BAD vs Loan

# %%
sns.boxplot(x=data["price"],y=data['clarity'],palette="PuBu")
# Out:
# C:\Users\adann\AppData\Local\Temp\ipykernel_8460\2097004802.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=data["price"],y=data['clarity'],palette="PuBu")
# <Axes: xlabel='price', ylabel='clarity'>

# %% [markdown]
# **Insights**
# - The price is not determined by clarity.
# - Each clarity can have a high-ranged price.

# %% [markdown]
# ####

# %% [markdown]
# #### **Note:** As shown above, perform Bi-Variate Analysis on different pair of Categorical and continuous variables

# %% [markdown]
# **Insights**
# - There is a bigger range of 50% of the people that purchase the Premium brand which has a much higher outlier price compared to the other cuts...

# %% [markdown]
# ### **Bivariate Analysis: Two Continuous Variables**

# %%
sns.scatterplot(x = data["price"], y = data['carat'],palette="PuBu")
#sns.scatterplot(x = 'Item_Visibility', y = 'Item_Outlet_Sales', data = train_df, ax = axes[1]);

# %% [markdown]
# **Observation**
# - The scatterplot shows better separation of the outlier values for both the price and carats.

# %%
sns.scatterplot(x = data["table"], y = data['depth'],palette="PuBu")
# Out:
# C:\Users\adann\AppData\Local\Temp\ipykernel_14216\2379685154.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x = data["table"], y = data['depth'],palette="PuBu")
# <Axes: xlabel='table', ylabel='depth'>

# %%
#Price and depth are slightly CORRELATED
sns.scatterplot(x = data["price"], y = data['depth'],palette="PuBu")
# Out:
# C:\Users\adann\AppData\Local\Temp\ipykernel_14216\530304565.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x = data["price"], y = data['depth'],palette="PuBu")
# <Axes: xlabel='price', ylabel='depth'>

# %% [markdown]
# **Insights: _____**

# %%
sns.scatterplot(x = data["price"], y = data['clarity'],palette="PuBu")
# Out:
# C:\Users\adann\AppData\Local\Temp\ipykernel_8460\22036741.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x = data["price"], y = data['clarity'],palette="PuBu")
# <Axes: xlabel='price', ylabel='clarity'>

# %%
#The plots below is to view more than 2 variables..

# %%
sns.scatterplot(data = data, x = "table", y = 'depth', hue = 'cut', palette="PuBu")
# Out:
# <Axes: xlabel='table', ylabel='depth'>

# %%
# Pair plot with hue
#sns.pairplot(data, hue = 'cut')

# %%
#datachart = data.groupby(['depth', 'table', 'cut', 'price'])
#sns.boxplot(datachart)

#Use relplot
sns.relplot(data, x = 'price', y ='depth', hue='table', col='cut')

# %%
#datachart = data.groupby(['depth', 'table', 'cut', 'price'])
#sns.boxplot(datachart)

#Use relplot
sns.relplot(data, x = 'price', y ='depth', hue='table', col='cut', row='clarity')

# %% [markdown]
# **The stacked bar chart (aka stacked bar graph)** extends the standard bar chart from looking at numeric values across one categorical variable to two.

# %% [markdown]
# ### **Multivariate Analysis**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cut            53940 non-null  object
#  1   color          53940 non-null  object
#  2   clarity        53940 non-null  object
#  3   carat          53940 non-null  float64
#  4   depth          53940 non-null  float64
#  5   table          53940 non-null  float64
#  6   x_(Premium)    53940 non-null  float64
#  7   z_(Very Good)  53940 non-null  float64
#  8   y_(Good)       53940 non-null  float64
#  9   price          53940 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# #### Add hist and boxplot chart for all Numerical Variables

# %%
plt.figure(figsize=(15, 10))
for i, feature in enumerate(numerical_features[:7], 1):
    plt.subplot(3, 3, i)
    sns.histplot(data[feature], kde=True)
    plt.title(f'{feature} Distribution')
    skewness = stats.skew(data[feature].dropna())
    plt.text(0.7, 0.9, f'Skewness: {skewness:.2f}', transform=plt.gca().transAxes)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Histplot after removal of outliers

# %%
data_cln = data.copy() #make a copy of the current dataframe
data_clncap = data.copy() #to observer capped plots as described in the video
#numerical_features

# %%
 Q1= np.percentile(data[numerical_features], 25) # 25th quantile
 Q3= np.percentile(data[numerical_features], 75)  # 75th quantile
 IQR=Q3 - Q1   # IQR Range
 Lower_Whisker = Q1 - (1.5 * IQR)  #define lower whisker
 Upper_Whisker = Q3 + (1.5 * IQR)  # define upper Whisker
 data_cln[numerical_features] = np.clip(data[numerical_features], Lower_Whisker, Upper_Whisker) # all the values samller than Lower_Whisker will be assigned value of Lower_whisker 
                                                            # and all the values above upper_whishker will be assigned value of upper_Whisker 
 #data_clncap.loc[data_clncap['carat'] > Upper_Whisker, 'carat'] = Upper_Whisker
 #data_clncap.loc[data_clncap[numerical_features] < Lower_Whisker, numerical_features] = Lower_Whisker
#data_cln.loc[data_cln[co

# %%
plt.figure(figsize=(15, 10))
for i, feature in enumerate(numerical_features[:7], 1):
    data_clncap.loc[data_clncap[feature] > Upper_Whisker, feature] = Upper_Whisker
    data_clncap.loc[data_clncap[feature] < Lower_Whisker, feature] = Lower_Whisker
    plt.subplot(3, 3, i)
    sns.histplot(data_clncap[feature], kde=True)
    plt.title(f'{feature} Distribution')
    skewness = stats.skew(data_clncap[feature].dropna())
    plt.text(0.7, 0.9, f'Skewness: {skewness:.2f}', transform=plt.gca().transAxes)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\adann\AppData\Local\Temp\ipykernel_8460\3885942951.py:8: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data_clncap[feature].dropna())

# %%
plt.figure(figsize=(15, 10))
for i, feature in enumerate(numerical_features[:7], 1):
    plt.subplot(3, 3, i)
    sns.histplot(data_cln[feature], kde=True)
    plt.title(f'{feature} Distribution')
    skewness = stats.skew(data_cln[feature].dropna())
    plt.text(0.7, 0.9, f'Skewness: {skewness:.2f}', transform=plt.gca().transAxes)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\adann\AppData\Local\Temp\ipykernel_8460\3817525405.py:6: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = stats.skew(data_cln[feature].dropna())

# %%
#Create Label Encoder for ordinal categores -cut, color and clarity
data_encoded2 = data.copy()
le = LabelEncoder()
#----------------cut-------
cut_order = ["Fair", "Good", "Very Good", "Ideal", "Premium"]
data_encoded2['cut_label'] = pd.Categorical(
    data_encoded2['cut'],
    categories = cut_order,
    ordered = True).codes
#print
data_encoded2[['cut', 'cut_label']]
print(data_encoded2['cut_label'].value_counts(dropna = False))

#----------------clarity category-------
#Where is "IF" ranked?? NOT mentioned in description..
clarity_order = ["I1", "IF", "SI1", "SI2","VS1", "VS2", "VVS1", "VVS2"] #SI2 SI1 VS1 VS2 VVS2 VVS1 and I1
data_encoded2['clarity_label'] = pd.Categorical(
    data_encoded2['clarity'],
    categories = clarity_order,
    ordered = True).codes
#print
data_encoded2[['clarity', 'clarity_label']]
print(data_encoded2['clarity_label'].value_counts(dropna = False))

#----------------color category-------
color_order = ["J", "I", "E", "F","G", "H", "D"]
data_encoded2['color_label'] = pd.Categorical(
    data_encoded2['color'],
    categories = color_order,
    ordered = True).codes
#print
data_encoded2[['color', 'color_label']]
print(data_encoded2['color_label'].value_counts(dropna = False))
# Out:
# cut_label
# 3    21551
# 4    13791
# 2    12082
# 1     4906
# 0     1610
# Name: count, dtype: int64
# clarity_label
# 2    13065
# 5    12258
# 3     9194
# 4     8171
# 7     5066
# 6     3655
# 1     1790
# 0      741
# Name: count, dtype: int64
# color_label
# 4    11292
# 2     9797
# 3     9542
# 5     8304
# 6     6775
# 1     5422
# 0     2808
# Name: count, dtype: int64

# %%
#Next is to drop cut, color and clarity columns..
data_encoded2.drop(['cut'], axis = 1, inplace = True) #data.drop(['cut', 'color', 'clarity'], axis = 1, inplace = True)
data_encoded2.drop(['color'], axis = 1, inplace = True)
data_encoded2.drop(['clarity'], axis = 1, inplace = True)

data_encoded2.head()
#print(data.dtypes)
#data.info()
# Out:
#    carat  depth  table  x_(Premium)  z_(Very Good)  y_(Good)  price  \
# 0   0.22   65.1   61.0         3.87           2.49      3.78    337
# 1   0.86   55.1   69.0         6.45           3.52      6.33   2757
# 2   0.96   66.3   62.0         6.27           4.07      5.95   2759
# 3   0.70   64.5   57.0         5.57           3.58      5.53   2762
# 4   0.70   65.3   55.0         5.63           3.66      5.58   2762
#
#    cut_label  clarity_label  color_label
# 0          0              5            2
# 1          0              3            2
# 2          0              3            3
# 3          0              5            3
# 4          0              5            3

# %% [markdown]
# #### Analyze Correlation Heatmap for Numerical Variables

# %%
data_encoded2.head()
# Out:
#    carat  depth  table  x_(Premium)  z_(Very Good)  y_(Good)  price  \
# 0   0.22   65.1   61.0         3.87           2.49      3.78    337
# 1   0.86   55.1   69.0         6.45           3.52      6.33   2757
# 2   0.96   66.3   62.0         6.27           4.07      5.95   2759
# 3   0.70   64.5   57.0         5.57           3.58      5.53   2762
# 4   0.70   65.3   55.0         5.63           3.66      5.58   2762
#
#    cut_label  clarity_label  color_label
# 0          0              5            2
# 1          0              3            2
# 2          0              3            3
# 3          0              5            3
# 4          0              5            3

# %%
#Reorder the columns..
data_encoded2 = data_encoded2[['cut_label', 'color_label', 'clarity_label', 'carat', 'depth', 'table', 'x_(Premium)', 'z_(Very Good)', 'y_(Good)', 'price',]]

#data_encoded2.head()

#Try combining the x, z and y columns
##Step 1 is with MULTIPLICATION------

df = data_encoded2.copy()
df['shapedim_xyz'] = data_encoded2['x_(Premium)'] * data_encoded2['z_(Very Good)'] * data_encoded2['y_(Good)'] 
data_encoded2xyz = pd.concat([df['shapedim_xyz'], data_encoded2], axis = 1)
data_encoded2xyz.head()
#data_encoded2 = pd.concat([clarity_label, data], axis = 1)

##Next is to drop x_(Premium)', 'z_(Very Good)', 'y_(Good) columns..
data_encoded2xyz.drop(['x_(Premium)'], axis = 1, inplace = True) 
data_encoded2xyz.drop(['z_(Very Good)'], axis = 1, inplace = True)
data_encoded2xyz.drop(['y_(Good)'], axis = 1, inplace = True)

# %%
# Separating numerical variables
#numerical_col = data_enc.select_dtypes(include=np.number).columns.tolist()
#numerical_col = data_encoded2.select_dtypes(include=np.number).columns.tolist()
numerical_col = data_encoded2xyz.select_dtypes(include=np.number).columns.tolist()


#corr = data_enc[numerical_col].corr()
#corr = data_encoded2[numerical_col].corr()
corr = data_encoded2xyz[numerical_col].corr()
#corr = data_encoded2noxyz[numerical_col].corr()
#print(corr)
# plot the heatmap

plt.figure(figsize=(10,6)) #(16,12))
sns.heatmap(corr,cmap='coolwarm',vmax=1,vmin=-1,
        annot = True,
        fmt=".2f",
        xticklabels=corr.columns,
        yticklabels=corr.columns);

# %% [markdown]
# ### **Think about it**
# - Are there missing values and outliers in the dataset? If yes, how can you treat them?
# - Can you think of different ways in which this can be done and when to treat these outliers or not?
# - Can we create new features based on Missing values?

# %% [markdown]
# #### Treating Outliers

# %% [markdown]
# #### Filling missing values in numerical columns with median and mode in categorical variables

# %% [markdown]
# ## **Important Insights from EDA**
#
# What are the the most important observations and insights from the data based on the EDA performed?

# %% [markdown]
# ## **Model Building - Approach**
# 1. Data preparation
# 2. Partition the data into train and test set
# 3. Fit on the train data
# 4. Tune the model and prune the tree, if required
# 5. Test the model on test set

# %% [markdown]
# #### Linear Regression

# %%
#Get the Input and Output Variables
#At this point, inspect and exclude variables like ids that have no corrlation/nothing to do with predicting the dependent variable.
#Check if distribution of the dependent variable is balanced - there is no prevalent class (applies more to Logistic Regrssion for Classification).
X = data_encoded2xyz.iloc[:, :-1].values
y = data_encoded2xyz.iloc[:, -1].values

# %%
#Create Training and Test sets:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0) #random_state-a seed to ensure the same training and test sets always display.

# %%
#X_train
y_train
# Out:
# array([2066,  600, 1971, ..., 3334, 4158, 4452], dtype=int64)

# %%
y_test
# Out:
# array([ 5057,   670,  9326, ...,  1385,   895, 13732], dtype=int64)

# %%
#Scale the data before building the Models:
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)

# %%
#Building and training the model
from sklearn.linear_model import LinearRegression
model_LR = LinearRegression()

# %%
#Training the model
model_LR.fit(X_train, y_train) #model now trained
# Out:
# LinearRegression()

# %%
#Inference
y_pred = model_LR.predict(sc.transform(X_test))
y_pred #view the predictions and compare with y_test
# Out:
# array([ 6181.33447918,   541.32755347,  7159.03892217, ...,
#         1938.87806387,   493.195252  , 14066.5139717 ])

# %%
X_test0 = sc.transform(X_test)
X_test0[1]
# Out:
# array([-1.06105067,  0.23568073,  1.55854592,  0.67618613, -1.05073967,
#         0.38098755,  0.2440363 ])

# %%
#Verify with single observation/data point- grab the first row:
#model_LR.predict([[0,2,5,0.22,65.1,61.0,3.87,2.49,3.78]]) #0	2	5	0.22	65.1	61.0	3.87	2.49	3.78	337
#model_LR.predict([[0.23568073,1.55854592,0.67618613,-1.05073967,0.38098755,0.2440363,-1.2887778]])
model_LR.predict([[-1.06105067, 0.23568073, 1.55854592,0.67618613,-1.05073967, 0.38098755,0.2440363]])
#model_LR.predict([[0.23568073,1.55854592,0.67618613,-1.05073967,0.38098755,0.2440363]]) #for dataencoded2noxyz

#I need to use X_test scaled values??
# Out:
# array([541.32754726])

# %%
#Evaluating the Model
#R-Squared
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
#Check result, if high >.90, proves/confirms predicted is close to actual(y_test/ground truth)
r2
# Out:
# 0.8720350371267949

# %%
#Check Adjusted R-squared
k = X_test0.shape[1]#number of columns of independent variables
n = X_test0.shape[0] # of observations
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)
adj_r2
# Out:
# -2.2623152334642573

# %% [markdown]
# #### Decision Tree

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor  #DecisionTreeClassifier
from sklearn import metrics

dtree_regressor = DecisionTreeRegressor(random_state = 0, max_depth = 7)
dtree_regressor.fit(X_train, y_train)
y_pred_dt = dtree_regressor.predict(sc.transform(X_test))

features = list(data_encoded2xyz.columns)

plt.figure(figsize = (20, 20))
tree.plot_tree(dtree_regressor, feature_names=features, filled = True, fontsize = 9, node_ids = True)
#plt.show(), not needed. Will display regardless
# Out:
# [Text(0.4984631147540984, 0.9375, 'node #0\nshapedim_xyz <= 0.387\nsquared_error = 16009989.391\nsamples = 43152\nvalue = 3941.836'),
#  Text(0.25922131147540983, 0.8125, 'node #1\ncarat <= -0.366\nsquared_error = 1547181.557\nsamples = 28602\nvalue = 1714.1'),
#  Text(0.13114754098360656, 0.6875, 'node #2\nshapedim_xyz <= -0.692\nsquared_error = 265256.437\nsamples = 19822\nvalue = 1052.067'),
#  Text(0.06557377049180328, 0.5625, 'node #3\nshapedim_xyz <= -0.893\nsquared_error = 56201.402\nsamples = 13986\nvalue = 787.511'),
#  Text(0.03278688524590164, 0.4375, 'node #4\nshapedim_xyz <= -1.06\nsquared_error = 35552.407\nsamples = 9576\nvalue = 702.482'),
#  Text(0.01639344262295082, 0.3125, 'node #5\nshapedim_xyz <= -1.144\nsquared_error = 16345.996\nsamples = 1622\nvalue = 560.976'),
#  Text(0.00819672131147541, 0.1875, 'node #6\nclarity_label <= 0.966\nsquared_error = 7780.154\nsamples = 620\nvalue = 504.408'),
#  Text(0.004098360655737705, 0.0625, 'node #7\nsquared_error = 5977.409\nsamples = 219\nvalue = 446.858'),
#  Text(0.012295081967213115, 0.0625, 'node #8\nsquared_error = 5968.086\nsamples = 401\nvalue = 535.838'),
#  Text(0.02459016393442623, 0.1875, 'node #9\nclarity_label <= 0.966\nsquared_error = 18441.077\nsamples = 1002\nvalue = 595.978'),
#  Text(0.020491803278688523, 0.0625, 'node #10\nsquared_error = 16952.759\nsamples = 597\nvalue = 555.918'),
#  Text(0.028688524590163935, 0.0625, 'node #11\nsquared_error = 14782.266\nsamples = 405\nvalue = 655.03'),
#  Text(0.04918032786885246, 0.3125, 'node #12\ncolor_label <= -1.094\nsquared_error = 34553.024\nsamples = 7954\nvalue = 731.338'),
#  Text(0.040983606557377046, 0.1875, 'node #13\nclarity_label <= -1.354\nsquared_error = 13454.232\nsamples = 782\nvalue = 542.079'),
#  Text(0.036885245901639344, 0.0625, 'node #14\nsquared_error = 12928.695\nsamples = 64\nvalue = 711.734'),
#  Text(0.045081967213114756, 0.0625, 'node #15\nsquared_error = 10706.785\nsamples = 718\nvalue = 526.957'),
#  Text(0.05737704918032787, 0.1875, 'node #16\nclarity_label <= -1.354\nsquared_error = 32522.184\nsamples = 7172\nvalue = 751.974'),
#  Text(0.05327868852459016, 0.0625, 'node #17\nsquared_error = 32976.926\nsamples = 608\nvalue = 959.26'),
#  Text(0.06147540983606557, 0.0625, 'node #18\nsquared_error = 28131.487\nsamples = 6564\nvalue = 732.774'),
#  Text(0.09836065573770492, 0.4375, 'node #19\nclarity_label <= 0.966\nsquared_error = 51249.326\nsamples = 4410\nvalue = 972.147'),
#  Text(0.08196721311475409, 0.3125, 'node #20\nclarity_label <= -1.354\nsquared_error = 39146.844\nsamples = 3214\nvalue = 911.329'),
#  Text(0.07377049180327869, 0.1875, 'node #21\nclarity_label <= -1.934\nsquared_error = 69924.584\nsamples = 224\nvalue = 1206.165'),
#  Text(0.06967213114754098, 0.0625, 'node #22\nsquared_error = 6670.462\nsamples = 13\nvalue = 568.0'),
#  Text(0.0778688524590164, 0.0625, 'node #23\nsquared_error = 47184.307\nsamples = 211\nvalue = 1245.483'),
#  Text(0.09016393442622951, 0.1875, 'node #24\nclarity_label <= -0.194\nsquared_error = 29840.823\nsamples = 2990\nvalue = 889.24'),
#  Text(0.0860655737704918, 0.0625, 'node #25\nsquared_error = 18130.232\nsamples = 1327\nvalue = 797.249'),
#  Text(0.0942622950819672, 0.0625, 'node #26\nsquared_error = 27044.319\nsamples = 1663\nvalue = 962.646'),
#  Text(0.11475409836065574, 0.3125, 'node #27\ncolor_label <= -1.094\nsquared_error = 47120.447\nsamples = 1196\nvalue = 1135.584'),
#  Text(0.10655737704918032, 0.1875, 'node #28\ntable <= -0.875\nsquared_error = 19330.987\nsamples = 160\nvalue = 889.275'),
#  Text(0.10245901639344263, 0.0625, 'node #29\nsquared_error = 13351.311\nsamples = 38\nvalue = 799.711'),
#  Text(0.11065573770491803, 0.0625, 'node #30\nsquared_error = 17916.667\nsamples = 122\nvalue = 917.172'),
#  Text(0.12295081967213115, 0.1875, 'node #31\nshapedim_xyz <= -0.732\nsquared_error = 40595.58\nsamples = 1036\nvalue = 1173.625'),
#  Text(0.11885245901639344, 0.0625, 'node #32\nsquared_error = 32782.592\nsamples = 1000\nvalue = 1158.5'),
#  Text(0.9836065573770492, 0.3125, 'node #240\ncarat <= 0.751\nsquared_error = 5252508.423\nsamples = 1348\nvalue = 15409.611'),
#  Text(0.9754098360655737, 0.1875, 'node #241\ntable <= -1.166\nsquared_error = 2756.25\nsamples = 2\nvalue = 2022.5'),
#  Text(0.9713114754098361, 0.0625, 'node #242\nsquared_error = 0.0\nsamples = 1\nvalue = 1970.0'),
#  Text(0.9795081967213115, 0.0625, 'node #243\nsquared_error = 0.0\nsamples = 1\nvalue = 2075.0'),
#  Text(0.9918032786885246, 0.1875, 'node #244\nclarity_label <= -0.194\nsquared_error = 4993620.922\nsamples = 1346\nvalue = 15429.503'),
#  Text(0.9877049180327869, 0.0625, 'node #245\nsquared_error = 5144651.776\nsamples = 1119\nvalue = 15212.643'),
#  Text(0.9959016393442623, 0.0625, 'node #246\nsquared_error = 2874487.51\nsamples = 227\nvalue = 16498.52')]

# %%
##Business RUles learned from the Decision Tree:

# %% [markdown]
# #### USE GRIDSearchCV for HyperParameterTuning of the Decision Tree:

# %%
#Choose the Decision Tree model and initialize the tree
d_tree_tuned = DecisionTreeRegressor(random_state = 0)


# Grid of parameters to choose from
parameters = {'max_depth': np.arange(2, 10), 
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [5, 10, 20, 25]
             }

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(r2_score) #, pos_label = 1)

# Run the grid search
grid_obj_dt = GridSearchCV(d_tree_tuned, parameters, scoring = scorer, cv = 5)

# Fit the best algorithm with GridSearch on train dataset

grid_obj_dt = grid_obj_dt.fit(X_train, y_train)


# Get the best combination of parameters/best estimator
best_dtree_tuned_params = grid_obj_dt.best_estimator_

print(f"Best parameters: {best_dtree_tuned_params}")
# Out:
# Best parameters: DecisionTreeRegressor(max_depth=9, min_samples_leaf=5, random_state=0)

# %%
##Make the Prediction /Inference from the TUNED DecisionTree
# Checking performance on the training data based on the tuned model

y_pred_dt = best_dtree_tuned.predict(sc.transform(X_test))

r2dt = r2_score(y_test, y_pred_dt)
print("Tuned Decision_Tree R2_score: {:.3f}".format(r2dt))
# Out:
# Tuned Decision_Tree R2_score: 0.969

# %% [markdown]
# **Check Feature Importance of the tuned Decision Tree**

# %%
data_encoded2xyz.columns
# Out:
# Index(['shapedim_xyz', 'cut_label', 'color_label', 'clarity_label', 'carat',
#        'depth', 'table', 'price'],
#       dtype='object')

# %%
#data_ind = data_encoded2xyz.copy()
#data_ind.drop(['price'], axis = 1, inplace = True)
#data_ind.columns
print (pd.DataFrame(best_dtree_tuned.feature_importances_, columns = ["Imp"], index = data_ind.columns).sort_values(by = 'Imp', ascending = False))

#print (pd.DataFrame(best_dtree_tuned.feature_importances_, index = data_encoded2xyz.columns).sort_values(by = 'Imp', ascending = False)) #, columns = ["Imp"], index = data_encoded2xyz.columns).sort_values(by = 'Imp', ascending = False))
# Out:
#                     Imp
# shapedim_xyz   0.851876
# clarity_label  0.064918
# carat          0.051956
# color_label    0.030518
# depth          0.000338
# cut_label      0.000237
# table          0.000157

# %%
# Plotting the feature importance
importances = best_dtree_tuned.feature_importances_

indices = np.argsort(importances)

plt.figure(figsize = (10, 10))

plt.title('Feature Importances')

plt.barh(range(len(indices)), importances[indices], color = 'violet', align = 'center')

plt.yticks(range(len(indices)), [features[i] for i in indices])

plt.xlabel('Relative Importance')

plt.show()

# %%
#XGBoost

# %%
#Create Training and Test sets:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

# %%
#Building XGBoost Model

# %%
#!pip install xgboost
import xgboost
modelxg = xgboost.XGBRegressor() #xgboost model for Regression

# %%
#Training the model
modelxg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
#Inference/Prediction
y_predxg = modelxg.predict(sc.transform(X_test))
#Compare y_pred and y_test

# %%
#Evaluating XGBoost model

#1. R-Squared
from sklearn.metrics import r2_score
r2_xg = r2_score(y_test, y_predxg)
print("R2..", r2_xg)

#2. Adjusted R-squared
k = X_test0.shape[1] #(1) #GIves number of features in test set
n = X_test0.shape[0]
adj_r2_xg = 1 - (1-r2_xg)*(n-1)/(n-k-1)
print("Adj R2..", adj_r2_xg)

#3. k-Fold cross validationa 
#FOr evaluating the model performance on not just one split but on up to 10..to ensure the other acceptable metrics was not just a stroke of luck.
# Out:
# R2.. 0.9820320225509214
# Adj R2.. 0.9820203550330973

# %%
#k-Fold Cross Validation
from sklearn.model_selection import cross_val_score
#will return the 10 r2 result not their average
r2s = cross_val_score(estimator = modelxg,
                      X = X,
                      y = y,
                      scoring = 'r2',
                      cv = 10)

print("Average R-squared/the relevant R-squared: {:.2f}".format(r2s.mean())) #0.86 is good
print("Standard Deviation: {:.2f}".format(r2s.std())) #0.04 is low and very good too meaning the R-square ranges from ((Avg Rsq - std dev) to (AvgRsq + std dev)
#compare this Avg R-squared with the previous R-squared calculated.
# Out:
# Average R-squared/the relevant R-squared: 0.87
# Standard Deviation: 0.17

# %%
##HyperParameter Tuning - FOR XGBoost

# %%
#Rerun the k-FOld by extending the decimal format .3f with the default model value:
#k-Fold Cross Validation
from sklearn.model_selection import cross_val_score
#will return the 10 r2 result not their average
r2s = cross_val_score(estimator = modelxg,
                      X = X,
                      y = y,
                      scoring = 'r2',
                      cv = 10)

print("Average R-squared/the relevant R-squared: {:.3f}".format(r2s.mean())) #0.86 is good
print("Standard Deviation: {:.3f}".format(r2s.std()))
# Out:
# Average R-squared/the relevant R-squared: 0.866
# Standard Deviation: 0.173

# %%
#next is to run the model by adjusting the max_depth(depth of tree), learning_rate(speed model will learn, the higher the faster it will learn)
#and n-estimator(number of trees in xgboost algorithm) 
#and booster(the default is 'gbtree'gradient boosting tree. Try the 'dart' which gives higher weight to the earlier trees or the first set of trees.
#model_xghp = xgboost.XGBRegressor(max_depth=4) #xgboost model for Regression
#start with only maxdepth=4,then 2 and then 1 - check the Avg-Rsq each time
#max_depth=2, learning_rate(default = 0.1)=0.05 then 0.15, keep default 0.1
#max_depth=2, learning_rate = 0.1, n_estimators = default 100, then 50 then 150

model_xghp = xgboost.XGBRegressor(max_depth=4, learning_rate=0.1, n_estimators=100) #xgboost model for Regression

# %%
#hyperparameter TUNing continued:
#Training the model
model_xghp.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
#Inference/Prediction
y_predxghp = model_xghp.predict(sc.transform(X_test)) #X_test0 is the scaled X_test

# %%
#Evaluating XGBoost model - Hyperparameter Tuning

#1. R-Squared
from sklearn.metrics import r2_score
r2_xghp = r2_score(y_test, y_predxghp)
print("R2..", r2_xghp)

#2. Adjusted R-squared
k = X_test0.shape[1] #(1) #GIves number of features in test set
n = X_test0.shape[0]
adj_r2_xghp = 1 - (1-r2_xghp)*(n-1)/(n-k-1)
print("Adj R2..", adj_r2_xghp)

#3. k-Fold cross validationa 
#FOr evaluating the model performance on not just one split but on up to 10..to ensure the other acceptable metrics was not just a stroke of luck.
# Out:
# R2.. 0.9768734688799963
# Adj R2.. 0.9768584516519963

# %%
#k-Fold Cross Validation
from sklearn.model_selection import cross_val_score
#will return the 10 r2 result not their average
r2s_xghpk = cross_val_score(estimator = model_xghp,
                      X = X,
                      y = y,
                      scoring = 'r2',
                      cv = 10)

print("Average R-squared/the relevant R-squared: {:.2f}".format(r2s_xghpk.mean())) #0.86 is good
print("Standard Deviation: {:.2f}".format(r2s_xghpk.std()))
# Out:
# Average R-squared/the relevant R-squared: 0.83
# Standard Deviation: 0.23

# %%
#Insight
# The default values gave better score which ended up being lower than the regular XGboost model.
#XGB00sst R2- 0.87
#XGBoost_Tuned - best=0.83

# %%
##-------

# %%
##-----LightGBM-----

# %%
##Building the Model
#!pip install lightgbm
import lightgbm as lgb
model_light = lgb.LGBMRegressor()

# %%
#Training the LightGBM model
model_light.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000306 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 771
# [LightGBM] [Info] Number of data points in the train set: 43152, number of used features: 7
# [LightGBM] [Info] Start training from score 3941.836230
# LGBMRegressor()

# %%
##Inference
y_pred_light = model_light.predict(sc.transform(X_test))

# %%
##Evaluating LightGBM model

#1. R-Squared
from sklearn.metrics import r2_score
r2_light = r2_score(y_test, y_pred_light)
print("R2..", r2_light)

#2. Adjusted R-squared
k = X_test0.shape[1] #GIves number of features in test set
n = X_test0.shape[0]
adj_r2_light = 1 - (1-r2_light)*(n-1)/(n-k-1)
print("Adj R2..", adj_r2_light)

#3. k-Fold cross validationa 
#FOr evaluating the model performance on not just one split but on up to 10..to ensure the other acceptable metrics was not just a stroke of luck.
# Out:
# R2.. 0.9817537967205341
# Adj R2.. 0.9817419485365864

# %%
#k-Fold Cross Validation
from sklearn.model_selection import cross_val_score
#will return the 10 r2 result not their average
r2s_lightk = cross_val_score(estimator = model_light,
                      X = X,
                      y = y,
                      scoring = 'r2',
                      cv = 10)

print("Average R-squared/the relevant R-squared: {:.2f} %".format(r2s_lightk.mean()*100)) #0.86 is good
print("Standard Deviation: {:.2f}".format(r2s_lightk.std())) #0.04 is low and very good too meaning the R-square ranges from ((Avg Rsq - std dev) to (AvgRsq + std dev)
#compare this Avg R-squared with the previous R-squared calculated.
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000267 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 694
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3869.429428
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000305 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4014.710151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000271 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3463.755696
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000325 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4277.533206
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000266 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4200.936802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000270 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3947.341594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000277 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3564.268385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000303 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4162.897314
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000289 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 776
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3602.564537
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000279 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4224.560108
# Average R-squared/the relevant R-squared: 86.12 %
# Standard Deviation: 0.17

# %%
#compare the lightGBM k-fold result with XGBoost

# %%
##HyperParameter Tuning of LightGBM

# %%
##Using GridSearch to improve k-fold result
from sklearn.model_selection import GridSearchCV
parameters = {'num_leaves':[29,30,31,32,33], 'learning_rate':[0.08, 0.09,0,1,0.11,0.12], 'n_estimators':[89,90,100,110,120]} #enter in a dictionary'name of parameter to test'
#default of max_depth=-1 means there is no limit to the number of depths to be tested.
#num_leaves(default value=31) - test 29,30,31,32 and 33
#learning_rate(default =0.1) - test 0.08, 0.09,0,1,0.11 and 0.12
#n_estimators(number of tress-default=100)-test 89,90,100,110 and 120
#Note-better to test the 5 values close/centered around the default values.
grid_search = GridSearchCV(estimator = model_light,
                           param_grid = parameters,
                           scoring = 'r2',
                           cv=10) #cv = number of k-folds to test

grid_search.fit(X, y)
best_r2 = grid_search.best_score_  #attribute
best_parameters = grid_search.best_params_
print("Best R-Squared: {:.2f} %".format(best_r2 * 100)) #to convert to percent%
print("Best parameters:", best_parameters)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000383 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 694
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3869.429428
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000287 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4014.710151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000316 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3463.755696
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000303 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4277.533206
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000295 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4200.936802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000264 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3947.341594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000332 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3564.268385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000296 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4162.897314
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000344 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 776
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3602.564537
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000306 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4224.560108
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000275 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 694
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3869.429428
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000310 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4014.710151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000275 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3463.755696
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000326 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4277.533206
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000274 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4200.936802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000330 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3947.341594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000323 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3564.268385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000268 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4162.897314
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000370 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 776
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3602.564537
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000288 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4224.560108
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000339 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 694
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3869.429428
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000336 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4014.710151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000271 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3463.755696
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000339 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4277.533206
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000302 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4200.936802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000298 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3947.341594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000328 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3564.268385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000320 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4162.897314
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000277 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 776
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3602.564537
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000282 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4224.560108
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000377 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 694
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3869.429428
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000394 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4014.710151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000275 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3463.755696
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001120 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4277.533206
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000275 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4200.936802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000325 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3947.341594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000307 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3564.268385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000322 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4162.897314
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000274 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 776
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3602.564537
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000403 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4224.560108
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000330 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 694
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3869.429428
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000362 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4014.710151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000271 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3463.755696
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000364 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4277.533206
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000266 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4200.936802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000279 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3947.341594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000354 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3564.268385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000333 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4162.897314
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000305 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 776
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3602.564537
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000327 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4224.560108
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000306 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 694
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3869.429428
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000293 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4014.710151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000273 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3463.755696
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000333 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4277.533206
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001206 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4200.936802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000283 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3947.341594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000302 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3564.268385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000289 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4162.897314
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000284 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 776
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3602.564537
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000305 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4224.560108
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000265 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 694
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3869.429428
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000399 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4014.710151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000273 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3463.755696
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000330 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4277.533206
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000275 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4200.936802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000288 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3947.341594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000296 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3564.268385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000289 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4162.897314
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000298 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 776
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3602.564537
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000306 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4224.560108
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000282 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 694
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3869.429428
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000299 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4014.710151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000299 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3463.755696
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000356 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4277.533206
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000290 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4200.936802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000351 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3947.341594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000346 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3564.268385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000292 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4162.897314
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000289 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 776
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3602.564537
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000323 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4224.560108
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000309 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 694
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3869.429428
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000321 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4014.710151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000285 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3463.755696
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000284 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4277.533206
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001265 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4200.936802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000333 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3947.341594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000326 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3564.268385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000285 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4162.897314
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000303 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 776
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3602.564537
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000388 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4224.560108
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000272 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 694
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3869.429428
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000287 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4014.710151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000294 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3463.755696
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000304 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4277.533206
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000351 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4200.936802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000364 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3947.341594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000335 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3564.268385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000332 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4162.897314
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000299 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 776
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3602.564537
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000414 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4224.560108
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000325 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 694
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3869.429428
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000318 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4014.710151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000292 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3463.755696
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000300 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4277.533206
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000290 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4200.936802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000300 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3947.341594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000285 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3564.268385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000291 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4162.897314
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000329 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 776
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3602.564537
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000300 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4224.560108
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000298 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 694
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3869.429428
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000377 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4014.710151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000345 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3463.755696
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000338 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4277.533206
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000344 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4200.936802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000298 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3947.341594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000344 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3564.268385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000345 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4162.897314
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000370 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# ...
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4014.710151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000361 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3463.755696
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000332 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4277.533206
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000332 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4200.936802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000390 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3947.341594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000344 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3564.268385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000408 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4162.897314
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000316 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 776
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3602.564537
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000302 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4224.560108
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000297 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 694
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3869.429428
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000503 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4014.710151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000347 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3463.755696
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000314 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4277.533206
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000328 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4200.936802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000346 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3947.341594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000351 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3564.268385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000373 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4162.897314
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000309 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 776
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3602.564537
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000318 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4224.560108
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000445 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 694
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3869.429428
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000419 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4014.710151
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001345 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3463.755696
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001402 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4277.533206
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000306 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 780
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4200.936802
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000366 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3947.341594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000353 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 773
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3564.268385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000352 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 782
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4162.897314
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000327 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 776
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 3602.564537
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000349 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 775
# [LightGBM] [Info] Number of data points in the train set: 48546, number of used features: 7
# [LightGBM] [Info] Start training from score 4224.560108
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000537 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 783
# [LightGBM] [Info] Number of data points in the train set: 53940, number of used features: 7
# [LightGBM] [Info] Start training from score 3932.799722
# Best R-Squared: 86.74 %
# Best parameters: {'learning_rate': 0.12, 'n_estimators': 120, 'num_leaves': 29}
# C:\Users\adann\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 250 fits failed out of a total of 1500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 250 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\adann\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\adann\anaconda3\Lib\site-packages\lightgbm\sklearn.py", line 1398, in fit
#     super().fit(
#   File "C:\Users\adann\anaconda3\Lib\site-packages\lightgbm\sklearn.py", line 1049, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "C:\Users\adann\anaconda3\Lib\site-packages\lightgbm\engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\adann\anaconda3\Lib\site-packages\lightgbm\basic.py", line 3656, in __init__
#     train_set.construct()
#   File "C:\Users\adann\anaconda3\Lib\site-packages\lightgbm\basic.py", line 2590, in construct
#     self._lazy_init(
#   File "C:\Users\adann\anaconda3\Lib\site-packages\lightgbm\basic.py", line 2187, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "C:\Users\adann\anaconda3\Lib\site-packages\lightgbm\basic.py", line 2318, in __init_from_np2d
#     _safe_call(
#   File "C:\Users\adann\anaconda3\Lib\site-packages\lightgbm\basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: Check failed: (learning_rate) > (0.0) at D:\a\1\s\lightgbm-python\src\io\config_auto.cpp, line 341 .
#
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\adann\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.84896184 0.85319887 0.85570177 0.85783703 0.85114256 0.84936889
#  0.85392865 0.85624339 0.85840572 0.8512543  0.85213698 0.85580455
#  0.85938486 0.86092878 0.85353161 0.85503938 0.85752731 0.86092395
#  0.86256622 0.85498503 0.85583219 0.85948277 0.86266349 0.86422474
#  0.85698128 0.85685727 0.85698553 0.85790083 0.85557476 0.8567523
#  0.85715004 0.85723544 0.85828843 0.85504365 0.85651891 0.85972193
#  0.85869141 0.86045594 0.85657315 0.85844585 0.86121521 0.86042809
#  0.86252714 0.8579865  0.86096621 0.86268165 0.86210812 0.86399651
#  0.85971616 0.86224215        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.77511034 0.81463997 0.82739813
#  0.80916216 0.81484069 0.7749632  0.81444716 0.82731898 0.80933763
#  0.81499919 0.7769241  0.81040076 0.83245625 0.80913742 0.81517519
#  0.77734949 0.80538218 0.83475674 0.80787267 0.81474796 0.7848439
#  0.80707573 0.83601187 0.80979965 0.81580791 0.85783521 0.85752646
#  0.86047796 0.85712202 0.8605108  0.8579698  0.85748827 0.86040838
#  0.85744637 0.86076581 0.86044445 0.85941031 0.86215404 0.85980489
#  0.86228931 0.86191266 0.86118051 0.86311471 0.86088737 0.86301546
#  0.8642732  0.86177578 0.86456693 0.861438   0.86410948 0.86172898
#  0.86019369 0.85773386 0.86048175 0.86206651 0.86201748 0.86031643
#  0.85797758 0.86046356 0.86210458 0.86407446 0.86172272 0.85981503
#  0.86166497 0.86410794 0.86560409 0.86263715 0.86287033 0.86292245
#  0.86586249 0.86736765 0.864771   0.86365224 0.86367667 0.86620555]
#   warnings.warn(

# %%
#-------DecisionTree------

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor  #DecisionTreeClassifier

dtree_regressor = DecisionTreeRegressor(random_state = 0, max_depth = 7)
dtree_regressor.fit(X_train, y_train)
y_pred_dt = dtree_regressor.predict(sc.transform(X_test))

features = list(data_encoded2xyz.columns)

plt.figure(figsize = (20, 20))
tree.plot_tree(dtree_regressor, feature_names=features, filled = True, fontsize = 9, node_ids = True)
#plt.show(), not needed. Will display regardless
# Out:
# [Text(0.4984631147540984, 0.9375, 'node #0\nclarity_xyz <= 0.387\nsquared_error = 16009989.391\nsamples = 43152\nvalue = 3941.836'),
#  Text(0.25922131147540983, 0.8125, 'node #1\ncarat <= -0.366\nsquared_error = 1547181.557\nsamples = 28602\nvalue = 1714.1'),
#  Text(0.13114754098360656, 0.6875, 'node #2\nclarity_xyz <= -0.692\nsquared_error = 265256.437\nsamples = 19822\nvalue = 1052.067'),
#  Text(0.06557377049180328, 0.5625, 'node #3\nclarity_xyz <= -0.893\nsquared_error = 56201.402\nsamples = 13986\nvalue = 787.511'),
#  Text(0.03278688524590164, 0.4375, 'node #4\nclarity_xyz <= -1.06\nsquared_error = 35552.407\nsamples = 9576\nvalue = 702.482'),
#  Text(0.01639344262295082, 0.3125, 'node #5\nclarity_xyz <= -1.144\nsquared_error = 16345.996\nsamples = 1622\nvalue = 560.976'),
#  Text(0.00819672131147541, 0.1875, 'node #6\nclarity_label <= 0.966\nsquared_error = 7780.154\nsamples = 620\nvalue = 504.408'),
#  Text(0.004098360655737705, 0.0625, 'node #7\nsquared_error = 5977.409\nsamples = 219\nvalue = 446.858'),
#  Text(0.012295081967213115, 0.0625, 'node #8\nsquared_error = 5968.086\nsamples = 401\nvalue = 535.838'),
#  Text(0.02459016393442623, 0.1875, 'node #9\nclarity_label <= 0.966\nsquared_error = 18441.077\nsamples = 1002\nvalue = 595.978'),
#  Text(0.020491803278688523, 0.0625, 'node #10\nsquared_error = 16952.759\nsamples = 597\nvalue = 555.918'),
#  Text(0.028688524590163935, 0.0625, 'node #11\nsquared_error = 14782.266\nsamples = 405\nvalue = 655.03'),
#  Text(0.04918032786885246, 0.3125, 'node #12\ncolor_label <= -1.094\nsquared_error = 34553.024\nsamples = 7954\nvalue = 731.338'),
#  Text(0.040983606557377046, 0.1875, 'node #13\nclarity_label <= -1.354\nsquared_error = 13454.232\nsamples = 782\nvalue = 542.079'),
#  Text(0.036885245901639344, 0.0625, 'node #14\nsquared_error = 12928.695\nsamples = 64\nvalue = 711.734'),
#  Text(0.045081967213114756, 0.0625, 'node #15\nsquared_error = 10706.785\nsamples = 718\nvalue = 526.957'),
#  Text(0.05737704918032787, 0.1875, 'node #16\nclarity_label <= -1.354\nsquared_error = 32522.184\nsamples = 7172\nvalue = 751.974'),
#  Text(0.05327868852459016, 0.0625, 'node #17\nsquared_error = 32976.926\nsamples = 608\nvalue = 959.26'),
#  Text(0.06147540983606557, 0.0625, 'node #18\nsquared_error = 28131.487\nsamples = 6564\nvalue = 732.774'),
#  Text(0.09836065573770492, 0.4375, 'node #19\nclarity_label <= 0.966\nsquared_error = 51249.326\nsamples = 4410\nvalue = 972.147'),
#  Text(0.08196721311475409, 0.3125, 'node #20\nclarity_label <= -1.354\nsquared_error = 39146.844\nsamples = 3214\nvalue = 911.329'),
#  Text(0.07377049180327869, 0.1875, 'node #21\nclarity_label <= -1.934\nsquared_error = 69924.584\nsamples = 224\nvalue = 1206.165'),
#  Text(0.06967213114754098, 0.0625, 'node #22\nsquared_error = 6670.462\nsamples = 13\nvalue = 568.0'),
#  Text(0.0778688524590164, 0.0625, 'node #23\nsquared_error = 47184.307\nsamples = 211\nvalue = 1245.483'),
#  Text(0.09016393442622951, 0.1875, 'node #24\nclarity_label <= -0.194\nsquared_error = 29840.823\nsamples = 2990\nvalue = 889.24'),
#  Text(0.0860655737704918, 0.0625, 'node #25\nsquared_error = 18130.232\nsamples = 1327\nvalue = 797.249'),
#  Text(0.0942622950819672, 0.0625, 'node #26\nsquared_error = 27044.319\nsamples = 1663\nvalue = 962.646'),
#  Text(0.11475409836065574, 0.3125, 'node #27\ncolor_label <= -1.094\nsquared_error = 47120.447\nsamples = 1196\nvalue = 1135.584'),
#  Text(0.10655737704918032, 0.1875, 'node #28\ntable <= -0.875\nsquared_error = 19330.987\nsamples = 160\nvalue = 889.275'),
#  Text(0.10245901639344263, 0.0625, 'node #29\nsquared_error = 13351.311\nsamples = 38\nvalue = 799.711'),
#  Text(0.11065573770491803, 0.0625, 'node #30\nsquared_error = 17916.667\nsamples = 122\nvalue = 917.172'),
#  Text(0.12295081967213115, 0.1875, 'node #31\nclarity_xyz <= -0.732\nsquared_error = 40595.58\nsamples = 1036\nvalue = 1173.625'),
#  Text(0.11885245901639344, 0.0625, 'node #32\nsquared_error = 32782.592\nsamples = 1000\nvalue = 1158.5'),
#  Text(0.12704918032786885, 0.0625, 'node #33\nsquared_error = 74763.41\nsamples = 36\nvalue = 1593.75'),
#  Text(0.19672131147540983, 0.5625, 'node #34\nclarity_label <= 0.966\nsquared_error = 196558.358\nsamples = 5836\nvalue = 1686.077'),
#  Text(0.16393442622950818, 0.4375, 'node #35\nclarity_label <= -0.194\nsquared_error = 137079.798\nsamples = 4805\nvalue = 1584.555'),
#  Text(0.14754098360655737, 0.3125, 'node #36\nclarity_label <= -1.354\nsquared_error = 164762.646\nsamples = 2178\nvalue = 1426.149'),
#  Text(0.13934426229508196, 0.1875, 'node #37\nclarity_label <= -1.934\nsquared_error = 615553.149\nsamples = 190\nvalue = 2157.879'),
#  Text(0.13524590163934427, 0.0625, 'node #38\nsquared_error = 22937.517\nsamples = 30\nvalue = 850.5'),
#  Text(0.14344262295081966, 0.0625, 'node #39\nsquared_error = 346095.675\nsamples = 160\nvalue = 2403.012'),
#  Text(0.1557377049180328, 0.1875, 'node #40\nclarity_label <= -0.774\nsquared_error = 65615.489\nsamples = 1988\nvalue = 1356.215'),
#  Text(0.15163934426229508, 0.0625, 'node #41\nsquared_error = 63298.899\nsamples = 1412\nvalue = 1421.552'),
#  Text(0.1598360655737705, 0.0625, 'node #42\nsquared_error = 35175.6\nsamples = 576\nvalue = 1196.047'),
#  Text(0.18032786885245902, 0.3125, 'node #43\ncolor_label <= -1.094\nsquared_error = 76076.365\nsamples = 2627\nvalue = 1715.888'),
#  Text(0.1721311475409836, 0.1875, 'node #44\ncarat <= -0.598\nsquared_error = 30215.935\nsamples = 178\nvalue = 1220.315'),
#  Text(0.1680327868852459, 0.0625, 'node #45\nsquared_error = 16614.175\nsamples = 52\nvalue = 1075.692'),
#  Text(0.1762295081967213, 0.0625, 'node #46\nsquared_error = 23635.175\nsamples = 126\nvalue = 1280.0'),
#  Text(0.1885245901639344, 0.1875, 'node #47\nclarity_xyz <= -0.52\nsquared_error = 60261.868\nsamples = 2449\nvalue = 1751.907'),
#  Text(0.18442622950819673, 0.0625, 'node #48\nsquared_error = 41206.334\nsamples = 1631\nvalue = 1671.228'),
#  Text(0.19262295081967212, 0.0625, 'node #49\nsquared_error = 59400.322\nsamples = 818\nvalue = 1912.773'),
#  Text(0.22950819672131148, 0.4375, 'node #50\ncolor_label <= 1.264\nsquared_error = 201859.961\nsamples = 1031\nvalue = 2159.221'),
#  Text(0.21311475409836064, 0.3125, 'node #51\ncolor_label <= 0.085\nsquared_error = 145006.147\nsamples = 939\nvalue = 2094.693'),
#  Text(0.20491803278688525, 0.1875, 'node #52\ncolor_label <= -1.094\nsquared_error = 200717.424\nsamples = 448\nvalue = 2260.241'),
#  Text(0.20081967213114754, 0.0625, 'node #53\nsquared_error = 39935.924\nsamples = 70\nvalue = 1569.7'),
#  Text(0.20901639344262296, 0.0625, 'node #54\nsquared_error = 125834.004\nsamples = 378\nvalue = 2388.119'),
#  Text(0.22131147540983606, 0.1875, 'node #55\ncarat <= -0.513\nsquared_error = 46351.904\nsamples = 491\nvalue = 1943.644'),
#  Text(0.21721311475409835, 0.0625, 'node #56\nsquared_error = 26482.641\nsamples = 386\nvalue = 1889.166'),
#  Text(0.22540983606557377, 0.0625, 'node #57\nsquared_error = 68376.44\nsamples = 105\nvalue = 2143.914'),
#  Text(0.2459016393442623, 0.3125, 'node #58\nclarity_xyz <= -0.508\nsquared_error = 305880.818\nsamples = 92\nvalue = 2817.826'),
#  Text(0.23770491803278687, 0.1875, 'node #59\nclarity_label <= 1.546\nsquared_error = 181018.314\nsamples = 57\nvalue = 2567.421'),
#  Text(0.2336065573770492, 0.0625, 'node #60\nsquared_error = 302614.833\nsamples = 12\nvalue = 2978.0'),
#  Text(0.24180327868852458, 0.0625, 'node #61\nsquared_error = 91651.662\nsamples = 45\nvalue = 2457.933'),
#  Text(0.2540983606557377, 0.1875, 'node #62\ntable <= -0.427\nsquared_error = 240809.662\nsamples = 35\nvalue = 3225.629'),
#  Text(0.25, 0.0625, 'node #63\nsquared_error = 226308.345\nsamples = 21\nvalue = 3452.81'),
#  Text(0.2581967213114754, 0.0625, 'node #64\nsquared_error = 69019.694\nsamples = 14\nvalue = 2884.857'),
#  Text(0.38729508196721313, 0.6875, 'node #65\ncarat <= 0.203\nsquared_error = 1217904.767\nsamples = 8780\nvalue = 3208.724'),
#  Text(0.32786885245901637, 0.5625, 'node #66\nclarity_label <= -0.194\nsquared_error = 430604.324\nsamples = 5843\nvalue = 2721.388'),
#  Text(0.29508196721311475, 0.4375, 'node #67\nclarity_xyz <= -0.116\nsquared_error = 310948.413\nsamples = 2983\nvalue = 2483.373'),
#  Text(0.2786885245901639, 0.3125, 'node #68\nclarity_label <= -1.934\nsquared_error = 212928.855\nsamples = 1921\nvalue = 2309.419'),
#  Text(0.27049180327868855, 0.1875, 'node #69\ndepth <= 0.311\nsquared_error = 60062.462\nsamples = 47\nvalue = 1196.468'),
#  Text(0.26639344262295084, 0.0625, 'node #70\nsquared_error = 90098.722\nsamples = 12\nvalue = 1429.333'),
#  Text(0.27459016393442626, 0.0625, 'node #71\nsquared_error = 24798.119\nsamples = 35\nvalue = 1116.629'),
#  Text(0.28688524590163933, 0.1875, 'node #72\nclarity_label <= -1.354\nsquared_error = 184918.01\nsamples = 1874\nvalue = 2337.331'),
#  Text(0.2827868852459016, 0.0625, 'node #73\nsquared_error = 436158.913\nsamples = 56\nvalue = 3415.375'),
#  Text(0.29098360655737704, 0.0625, 'node #74\nsquared_error = 140277.644\nsamples = 1818\nvalue = 2304.124'),
#  Text(0.3114754098360656, 0.3125, 'node #75\ncolor_label <= -1.094\nsquared_error = 334504.794\nsamples = 1062\nvalue = 2798.032'),
#  Text(0.30327868852459017, 0.1875, 'node #76\ncolor_label <= -1.684\nsquared_error = 127895.772\nsamples = 119\nvalue = 2279.227'),
#  Text(0.29918032786885246, 0.0625, 'node #77\nsquared_error = 48561.689\nsamples = 59\nvalue = 2095.271'),
#  Text(0.3073770491803279, 0.0625, 'node #78\nsquared_error = 139910.803\nsamples = 60\nvalue = 2460.117'),
#  Text(0.319672131147541, 0.1875, 'node #79\nclarity_label <= -0.774\nsquared_error = 322325.19\nsamples = 943\nvalue = 2863.502'),
#  Text(0.3155737704918033, 0.0625, 'node #80\nsquared_error = 384498.175\nsamples = 543\nvalue = 3040.713'),
#  Text(0.3237704918032787, 0.0625, 'node #81\nsquared_error = 137423.649\nsamples = 400\nvalue = 2622.938'),
#  Text(0.36065573770491804, 0.4375, 'node #82\ncolor_label <= -1.094\nsquared_error = 434690.846\nsamples = 2860\nvalue = 2969.638'),
#  Text(0.3442622950819672, 0.3125, 'node #83\ncolor_label <= -1.684\nsquared_error = 143789.387\nsamples = 545\nvalue = 2348.191'),
#  Text(0.3360655737704918, 0.1875, 'node #84\ncarat <= -0.05\nsquared_error = 66100.762\nsamples = 147\nvalue = 2038.571'),
#  Text(0.3319672131147541, 0.0625, 'node #85\nsquared_error = 36995.471\nsamples = 123\nvalue = 1964.024'),
#  Text(0.3401639344262295, 0.0625, 'node #86\nsquared_error = 40819.484\nsamples = 24\nvalue = 2420.625'),
#  Text(0.3524590163934426, 0.1875, 'node #87\nclarity_xyz <= -0.074\nsquared_error = 123998.806\nsamples = 398\nvalue = 2462.548'),
#  Text(0.3483606557377049, 0.0625, 'node #88\nsquared_error = 85854.412\nsamples = 319\nvalue = 2373.47'),
#  Text(0.35655737704918034, 0.0625, 'node #89\nsquared_error = 116605.474\nsamples = 79\nvalue = 2822.241'),
#  Text(0.3770491803278688, 0.3125, 'node #90\nclarity_xyz <= -0.18\nsquared_error = 390852.092\nsamples = 2315\nvalue = 3115.94'),
#  Text(0.36885245901639346, 0.1875, 'node #91\nclarity_label <= 0.966\nsquared_error = 268679.643\nsamples = 993\nvalue = 2808.23'),
#  Text(0.36475409836065575, 0.0625, 'node #92\nsquared_error = 167291.449\nsamples = 771\nvalue = 2689.894'),
#  Text(0.3729508196721312, 0.0625, 'node #93\nsquared_error = 403262.083\nsamples = 222\nvalue = 3219.207'),
#  Text(0.38524590163934425, 0.1875, 'node #94\nclarity_label <= 0.966\nsquared_error = 358076.415\nsamples = 1322\nvalue = 3347.072'),
#  Text(0.38114754098360654, 0.0625, 'node #95\nsquared_error = 246825.068\nsamples = 1033\nvalue = 3233.265'),
#  Text(0.38934426229508196, 0.0625, 'node #96\nsquared_error = 543959.365\nsamples = 289\nvalue = 3753.862'),
#  Text(0.44672131147540983, 0.5625, 'node #97\ncarat <= 2.058\nsquared_error = 1371724.573\nsamples = 2937\nvalue = 4178.252'),
#  Text(0.4262295081967213, 0.4375, 'node #98\nclarity_label <= -0.194\nsquared_error = 1115327.775\nsamples = 2932\nvalue = 4157.569'),
#  Text(0.4098360655737705, 0.3125, 'node #99\nclarity_label <= -1.934\nsquared_error = 583360.225\nsamples = 1943\nvalue = 3837.559'),
#  Text(0.4016393442622951, 0.1875, 'node #100\ncarat <= 0.983\nsquared_error = 278016.667\nsamples = 74\nvalue = 2268.851'),
#  Text(0.3975409836065574, 0.0625, 'node #101\nsquared_error = 197644.026\nsamples = 73\nvalue = 2235.123'),
#  Text(0.4057377049180328, 0.0625, 'node #102\nsquared_error = 0.0\nsamples = 1\nvalue = 4731.0'),
#  Text(0.4180327868852459, 0.1875, 'node #103\nclarity_label <= -0.774\nsquared_error = 494158.96\nsamples = 1869\nvalue = 3899.67'),
#  Text(0.4139344262295082, 0.0625, 'node #104\nsquared_error = 542788.038\nsamples = 977\nvalue = 4156.136'),
#  Text(0.42213114754098363, 0.0625, 'node #105\nsquared_error = 289945.424\nsamples = 892\nvalue = 3618.765'),
#  Text(0.4426229508196721, 0.3125, 'node #106\ncarat <= 0.414\nsquared_error = 1563992.762\nsamples = 989\nvalue = 4786.263'),
#  Text(0.4344262295081967, 0.1875, 'node #107\ncolor_label <= -1.094\nsquared_error = 702746.137\nsamples = 724\nvalue = 4360.499'),
#  Text(0.430327868852459, 0.0625, 'node #108\nsquared_error = 142695.231\nsamples = 183\nvalue = 3521.284'),
#  Text(0.4385245901639344, 0.0625, 'node #109\nsquared_error = 573373.654\nsamples = 541\nvalue = 4644.373'),
#  Text(0.45081967213114754, 0.1875, 'node #110\nclarity_label <= 0.966\nsquared_error = 2068644.906\nsamples = 265\nvalue = 5949.483'),
#  Text(0.44672131147540983, 0.0625, 'node #111\nsquared_error = 1052757.739\nsamples = 227\nvalue = 5654.498'),
#  Text(0.45491803278688525, 0.0625, 'node #112\nsquared_error = 4512258.706\nsamples = 38\nvalue = 7711.632'),
#  Text(0.4672131147540984, 0.4375, 'node #113\ntable <= 1.139\nsquared_error = 4370273.76\nsamples = 5\nvalue = 16306.8'),
#  Text(0.46311475409836067, 0.3125, 'node #114\ncolor_label <= -0.21\nsquared_error = 1240496.688\nsamples = 4\nvalue = 17225.75'),
#  Text(0.45901639344262296, 0.1875, 'node #115\nsquared_error = 0.0\nsamples = 1\nvalue = 15397.0'),
#  Text(0.4672131147540984, 0.1875, 'node #116\nclarity_label <= -0.774\nsquared_error = 167628.222\nsamples = 3\nvalue = 17835.333'),
#  Text(0.46311475409836067, 0.0625, 'node #117\nsquared_error = 0.0\nsamples = 1\nvalue = 17265.0'),
#  Text(0.4713114754098361, 0.0625, 'node #118\nsquared_error = 7482.25\nsamples = 2\nvalue = 18120.5'),
#  Text(0.4713114754098361, 0.3125, 'node #119\nsquared_error = 0.0\nsamples = 1\nvalue = 12631.0'),
#  Text(0.7377049180327869, 0.8125, 'node #120\nclarity_xyz <= 1.398\nsquared_error = 15507215.814\nsamples = 14550\nvalue = 8321.061'),
#  Text(0.6065573770491803, 0.6875, 'node #121\nclarity_label <= -0.194\nsquared_error = 4983928.677\nsamples = 9696\nvalue = 6283.23'),
#  Text(0.5409836065573771, 0.5625, 'node #122\nclarity_xyz <= 0.849\nsquared_error = 2872765.683\nsamples = 5434\nvalue = 5249.372'),
#  Text(0.5081967213114754, 0.4375, 'node #123\nclarity_label <= -1.354\nsquared_error = 2294592.303\nsamples = 4118\nvalue = 4916.202'),
#  Text(0.4918032786885246, 0.3125, 'node #124\nclarity_label <= -1.934\nsquared_error = 20691678.82\nsamples = 294\nvalue = 6810.687'),
#  Text(0.48360655737704916, 0.1875, 'node #125\nclarity_xyz <= 0.615\nsquared_error = 342572.548\nsamples = 161\nvalue = 3161.503'),
#  Text(0.47950819672131145, 0.0625, 'node #126\nsquared_error = 272496.201\nsamples = 96\nvalue = 2924.583'),
#  Text(0.48770491803278687, 0.0625, 'node #127\nsquared_error = 240730.181\nsamples = 65\nvalue = 3511.415'),
#  Text(0.5, 0.1875, 'node #128\ncolor_label <= 1.264\nsquared_error = 9691064.647\nsamples = 133\nvalue = 11228.12'),
#  Text(0.4959016393442623, 0.0625, 'node #129\nsquared_error = 3337020.426\nsamples = 106\nvalue = 9927.387'),
#  Text(0.5040983606557377, 0.0625, 'node #130\nsquared_error = 1917073.394\nsamples = 27\nvalue = 16334.704'),
#  Text(0.5245901639344263, 0.3125, 'node #131\nclarity_label <= -0.774\nsquared_error = 583018.697\nsamples = 3824\nvalue = 4770.548'),
#  Text(0.5163934426229508, 0.1875, 'node #132\ncolor_label <= -1.094\nsquared_error = 562654.61\nsamples = 1988\nvalue = 5117.651'),
#  Text(0.5122950819672131, 0.0625, 'node #133\nsquared_error = 344407.489\nsamples = 371\nvalue = 4474.889'),
#  Text(0.5204918032786885, 0.0625, 'node #134\nsquared_error = 496189.829\nsamples = 1617\nvalue = 5265.125'),
#  Text(0.5327868852459017, 0.1875, 'node #135\nclarity_xyz <= 0.595\nsquared_error = 333358.229\nsamples = 1836\nvalue = 4394.709'),
#  Text(0.5286885245901639, 0.0625, 'node #136\nsquared_error = 254044.399\nsamples = 1196\nvalue = 4228.731'),
#  Text(0.5368852459016393, 0.0625, 'node #137\nsquared_error = 333888.325\nsamples = 640\nvalue = 4704.88'),
#  Text(0.5737704918032787, 0.4375, 'node #138\ncolor_label <= -1.094\nsquared_error = 3247713.89\nsamples = 1316\nvalue = 6291.923'),
#  Text(0.5573770491803278, 0.3125, 'node #139\nclarity_xyz <= 1.039\nsquared_error = 841777.171\nsamples = 406\nvalue = 5401.135'),
#  Text(0.5491803278688525, 0.1875, 'node #140\nclarity_label <= -1.934\nsquared_error = 448393.546\nsamples = 256\nvalue = 5060.977'),
#  Text(0.5450819672131147, 0.0625, 'node #141\nsquared_error = 86027.432\nsamples = 9\nvalue = 3390.889'),
#  Text(0.5532786885245902, 0.0625, 'node #142\nsquared_error = 356263.526\nsamples = 247\nvalue = 5121.83'),
#  Text(0.5655737704918032, 0.1875, 'node #143\nclarity_label <= -1.934\nsquared_error = 978652.553\nsamples = 150\nvalue = 5981.673'),
#  Text(0.5614754098360656, 0.0625, 'node #144\nsquared_error = 291537.64\nsamples = 10\nvalue = 4551.6'),
#  Text(0.569672131147541, 0.0625, 'node #145\nsquared_error = 871218.69\nsamples = 140\nvalue = 6083.821'),
#  Text(0.5901639344262295, 0.3125, 'node #146\nclarity_label <= -0.774\nsquared_error = 3809158.12\nsamples = 910\nvalue = 6689.352'),
#  Text(0.5819672131147541, 0.1875, 'node #147\nclarity_label <= -1.934\nsquared_error = 5507300.185\nsamples = 443\nvalue = 7403.804'),
#  Text(0.5778688524590164, 0.0625, 'node #148\nsquared_error = 874771.136\nsamples = 53\nvalue = 4274.358'),
#  Text(0.5860655737704918, 0.0625, 'node #149\nsquared_error = 4625081.305\nsamples = 390\nvalue = 7829.087'),
#  Text(0.5983606557377049, 0.1875, 'node #150\ncarat <= 1.236\nsquared_error = 1254753.02\nsamples = 467\nvalue = 6011.617'),
#  Text(0.5942622950819673, 0.0625, 'node #151\nsquared_error = 584050.416\nsamples = 384\nvalue = 5706.607'),
#  Text(0.6024590163934426, 0.0625, 'node #152\nsquared_error = 1936065.225\nsamples = 83\nvalue = 7422.747'),
#  Text(0.6721311475409836, 0.5625, 'node #153\nclarity_label <= 0.966\nsquared_error = 4575313.489\nsamples = 4262\nvalue = 7601.387'),
#  Text(0.639344262295082, 0.4375, 'node #154\nclarity_xyz <= 0.88\nsquared_error = 2867412.838\nsamples = 3316\nvalue = 7019.021'),
#  Text(0.6229508196721312, 0.3125, 'node #155\ncolor_label <= -1.094\nsquared_error = 1649220.374\nsamples = 2419\nvalue = 6556.826'),
#  Text(0.6147540983606558, 0.1875, 'node #156\nclarity_xyz <= 0.589\nsquared_error = 602072.91\nsamples = 366\nvalue = 4899.287'),
#  Text(0.610655737704918, 0.0625, 'node #157\nsquared_error = 398056.609\nsamples = 149\nvalue = 4412.812'),
#  Text(0.6188524590163934, 0.0625, 'node #158\nsquared_error = 468083.36\nsamples = 217\nvalue = 5233.318'),
#  Text(0.6311475409836066, 0.1875, 'node #159\nclarity_xyz <= 0.653\nsquared_error = 1258780.676\nsamples = 2053\nvalue = 6852.325'),
#  Text(0.6270491803278688, 0.0625, 'node #160\nsquared_error = 853152.739\nsamples = 1495\nvalue = 6568.633'),
#  Text(0.6352459016393442, 0.0625, 'node #161\nsquared_error = 1552209.322\nsamples = 558\nvalue = 7612.396'),
#  Text(0.6557377049180327, 0.3125, 'node #162\ncolor_label <= -1.094\nsquared_error = 4022904.674\nsamples = 897\nvalue = 8265.454'),
#  Text(0.6475409836065574, 0.1875, 'node #163\nclarity_xyz <= 1.207\nsquared_error = 1056949.752\nsamples = 286\nvalue = 6324.671'),
#  Text(0.6434426229508197, 0.0625, 'node #164\nsquared_error = 536568.152\nsamples = 234\nvalue = 6028.303'),
#  Text(0.6516393442622951, 0.0625, 'node #165\nsquared_error = 1224776.989\nsamples = 52\nvalue = 7658.327'),
#  Text(0.6639344262295082, 0.1875, 'node #166\nclarity_xyz <= 1.278\nsquared_error = 2822833.788\nsamples = 611\nvalue = 9173.905'),
#  Text(0.6598360655737705, 0.0625, 'node #167\nsquared_error = 2071987.318\nsamples = 547\nvalue = 8887.671'),
#  Text(0.6680327868852459, 0.0625, 'node #168\nsquared_error = 2555070.09\nsamples = 64\nvalue = 11620.312'),
#  Text(0.7049180327868853, 0.4375, 'node #169\nclarity_xyz <= 0.664\nsquared_error = 5206035.913\nsamples = 946\nvalue = 9642.744'),
#  Text(0.6885245901639344, 0.3125, 'node #170\ncolor_label <= -1.094\nsquared_error = 2949838.126\nsamples = 471\nvalue = 8662.314'),
#  Text(0.680327868852459, 0.1875, 'node #171\nclarity_xyz <= 0.498\nsquared_error = 1203788.587\nsamples = 19\nvalue = 4891.789'),
#  Text(0.6762295081967213, 0.0625, 'node #172\nsquared_error = 425784.959\nsamples = 11\nvalue = 4117.364'),
#  Text(0.6844262295081968, 0.0625, 'node #173\nsquared_error = 315032.734\nsamples = 8\nvalue = 5956.625'),
#  Text(0.6967213114754098, 0.1875, 'node #174\ncolor_label <= 1.264\nsquared_error = 2400501.946\nsamples = 452\nvalue = 8820.81'),
#  Text(0.6926229508196722, 0.0625, 'node #175\nsquared_error = 1897755.803\nsamples = 404\nvalue = 8569.646'),
#  Text(0.7008196721311475, 0.0625, 'node #176\nsquared_error = 1632166.843\nsamples = 48\nvalue = 10934.771'),
#  Text(0.7213114754098361, 0.3125, 'node #177\ncolor_label <= -1.094\nsquared_error = 5544964.189\nsamples = 475\nvalue = 10614.918'),
#  Text(0.7131147540983607, 0.1875, 'node #178\nclarity_xyz <= 1.08\nsquared_error = 961247.129\nsamples = 45\nvalue = 6827.933'),
#  Text(0.7090163934426229, 0.0625, 'node #179\nsquared_error = 548853.339\nsamples = 34\nvalue = 6432.882'),
#  Text(0.7172131147540983, 0.0625, 'node #180\nsquared_error = 262531.455\nsamples = 11\nvalue = 8049.0'),
#  Text(0.7295081967213115, 0.1875, 'node #181\ncolor_label <= 0.085\nsquared_error = 4366763.335\nsamples = 430\nvalue = 11011.23'),
#  Text(0.7254098360655737, 0.0625, 'node #182\nsquared_error = 3112678.334\nsamples = 154\nvalue = 12140.584'),
#  Text(0.7336065573770492, 0.0625, 'node #183\nsquared_error = 3957762.265\nsamples = 276\nvalue = 10381.083'),
#  Text(0.8688524590163934, 0.6875, 'node #184\nclarity_xyz <= 2.246\nsquared_error = 11662543.187\nsamples = 4854\nvalue = 12391.686'),
#  Text(0.8032786885245902, 0.5625, 'node #185\nclarity_label <= -0.194\nsquared_error = 8772459.01\nsamples = 3085\nvalue = 11011.469'),
#  Text(0.7704918032786885, 0.4375, 'node #186\nclarity_label <= -1.934\nsquared_error = 5549665.37\nsamples = 1599\nvalue = 9629.243'),
#  Text(0.7540983606557377, 0.3125, 'node #187\nclarity_xyz <= 1.759\nsquared_error = 1723205.52\nsamples = 75\nvalue = 5458.2'),
#  Text(0.7459016393442623, 0.1875, 'node #188\nclarity_xyz <= 1.477\nsquared_error = 1094305.231\nsamples = 46\nvalue = 4754.174'),
#  Text(0.7418032786885246, 0.0625, 'node #189\nsquared_error = 930773.243\nsamples = 24\nvalue = 4245.917'),
#  Text(0.75, 0.0625, 'node #190\nsquared_error = 683465.595\nsamples = 22\nvalue = 5308.636'),
#  Text(0.7622950819672131, 0.1875, 'node #191\ncolor_label <= -1.684\nsquared_error = 687475.512\nsamples = 29\nvalue = 6574.931'),
#  Text(0.7581967213114754, 0.0625, 'node #192\nsquared_error = 108726.222\nsamples = 3\nvalue = 5406.333'),
#  Text(0.7663934426229508, 0.0625, 'node #193\nsquared_error = 578501.331\nsamples = 26\nvalue = 6709.769'),
#  Text(0.7868852459016393, 0.3125, 'node #194\nclarity_label <= -0.774\nsquared_error = 4839659.298\nsamples = 1524\nvalue = 9834.511'),
#  Text(0.7786885245901639, 0.1875, 'node #195\ncolor_label <= -1.094\nsquared_error = 4826983.22\nsamples = 872\nvalue = 10683.169'),
#  Text(0.7745901639344263, 0.0625, 'node #196\nsquared_error = 1842613.449\nsamples = 248\nvalue = 8624.552'),
#  Text(0.7827868852459017, 0.0625, 'node #197\nsquared_error = 3659386.303\nsamples = 624\nvalue = 11501.337'),
#  Text(0.7950819672131147, 0.1875, 'node #198\nclarity_xyz <= 1.753\nsquared_error = 2605117.051\nsamples = 652\nvalue = 8699.497'),
#  Text(0.7909836065573771, 0.0625, 'node #199\nsquared_error = 1715468.954\nsamples = 477\nvalue = 8226.872'),
#  Text(0.7991803278688525, 0.0625, 'node #200\nsquared_error = 2761626.445\nsamples = 175\nvalue = 9987.737'),
#  Text(0.8360655737704918, 0.4375, 'node #201\ncolor_label <= -1.094\nsquared_error = 7972325.976\nsamples = 1486\nvalue = 12498.804'),
#  Text(0.819672131147541, 0.3125, 'node #202\nclarity_xyz <= 1.828\nsquared_error = 2555220.814\nsamples = 491\nvalue = 9811.601'),
#  Text(0.8114754098360656, 0.1875, 'node #203\ncolor_label <= -1.684\nsquared_error = 1484727.737\nsamples = 371\nvalue = 9258.474'),
#  Text(0.8073770491803278, 0.0625, 'node #204\nsquared_error = 609532.581\nsamples = 149\nvalue = 8283.678'),
#  Text(0.8155737704918032, 0.0625, 'node #205\nsquared_error = 1006317.612\nsamples = 222\nvalue = 9912.73'),
#  Text(0.8278688524590164, 0.1875, 'node #206\ncolor_label <= -1.684\nsquared_error = 1994554.533\nsamples = 120\nvalue = 11521.683'),
#  Text(0.8237704918032787, 0.0625, 'node #207\nsquared_error = 619670.376\nsamples = 35\nvalue = 10246.286'),
#  Text(0.8319672131147541, 0.0625, 'node #208\nsquared_error = 1615093.8\nsamples = 85\nvalue = 12046.847'),
#  Text(0.8524590163934426, 0.3125, 'node #209\ncolor_label <= 0.674\nsquared_error = 5323731.387\nsamples = 995\nvalue = 13824.851'),
#  Text(0.8442622950819673, 0.1875, 'node #210\nclarity_xyz <= 1.777\nsquared_error = 3432734.599\nsamples = 657\nvalue = 14730.967'),
#  Text(0.8401639344262295, 0.0625, 'node #211\nsquared_error = 2579539.695\nsamples = 531\nvalue = 14290.944'),
#  Text(0.8483606557377049, 0.0625, 'node #212\nsquared_error = 2773635.465\nsamples = 126\nvalue = 16585.349'),
#  Text(0.860655737704918, 0.1875, 'node #213\ncolor_label <= 1.264\nsquared_error = 4301329.785\nsamples = 338\nvalue = 12063.556'),
#  Text(0.8565573770491803, 0.0625, 'node #214\nsquared_error = 2589014.845\nsamples = 297\nvalue = 11573.246'),
#  Text(0.8647540983606558, 0.0625, 'node #215\nsquared_error = 2348701.582\nsamples = 41\nvalue = 15615.317'),
#  Text(0.9344262295081968, 0.5625, 'node #216\nclarity_label <= -1.934\nsquared_error = 7586848.382\nsamples = 1769\nvalue = 14798.678'),
#  Text(0.9016393442622951, 0.4375, 'node #217\nclarity_xyz <= 4.083\nsquared_error = 10360358.233\nsamples = 89\nvalue = 8937.371'),
#  Text(0.8852459016393442, 0.3125, 'node #218\nclarity_xyz <= 2.908\nsquared_error = 2638316.662\nsamples = 68\nvalue = 7569.485'),
#  Text(0.8770491803278688, 0.1875, 'node #219\ncut_label <= -1.222\nsquared_error = 1730296.21\nsamples = 46\nvalue = 6921.087'),
#  Text(0.8729508196721312, 0.0625, 'node #220\nsquared_error = 379190.622\nsamples = 30\nvalue = 6461.667'),
#  Text(0.8811475409836066, 0.0625, 'node #221\nsquared_error = 3125836.125\nsamples = 16\nvalue = 7782.5'),
#  Text(0.8934426229508197, 0.1875, 'node #222\ncut_label <= -1.708\nsquared_error = 1819807.721\nsamples = 22\nvalue = 8925.227'),
#  Text(0.889344262295082, 0.0625, 'node #223\nsquared_error = 1577767.918\nsamples = 7\nvalue = 7917.714'),
#  Text(0.8975409836065574, 0.0625, 'node #224\nsquared_error = 1237992.107\nsamples = 15\nvalue = 9395.4'),
#  Text(0.9180327868852459, 0.3125, 'node #225\ncarat <= 6.031\nsquared_error = 9687145.728\nsamples = 21\nvalue = 13366.714'),
#  Text(0.9098360655737705, 0.1875, 'node #226\ntable <= -2.218\nsquared_error = 5723372.102\nsamples = 14\nvalue = 11728.571'),
#  Text(0.9057377049180327, 0.0625, 'node #227\nsquared_error = 0.0\nsamples = 1\nvalue = 15964.0'),
#  Text(0.9139344262295082, 0.0625, 'node #228\nsquared_error = 4677572.485\nsamples = 13\nvalue = 11402.769'),
#  Text(0.9262295081967213, 0.1875, 'node #229\ndepth <= 1.6\nsquared_error = 1513620.857\nsamples = 7\nvalue = 16643.0'),
#  Text(0.9221311475409836, 0.0625, 'node #230\nsquared_error = 192732.688\nsamples = 4\nvalue = 15655.75'),
#  Text(0.930327868852459, 0.0625, 'node #231\nsquared_error = 242521.556\nsamples = 3\nvalue = 17959.333'),
#  Text(0.9672131147540983, 0.4375, 'node #232\ncolor_label <= -1.684\nsquared_error = 5523509.342\nsamples = 1680\nvalue = 15109.188'),
#  Text(0.9508196721311475, 0.3125, 'node #233\nclarity_xyz <= 3.092\nsquared_error = 4769488.805\nsamples = 332\nvalue = 13889.395'),
#  Text(0.9426229508196722, 0.1875, 'node #234\nclarity_label <= -0.194\nsquared_error = 2831213.126\nsamples = 249\nvalue = 13125.586'),
#  Text(0.9385245901639344, 0.0625, 'node #235\nsquared_error = 1853036.519\nsamples = 142\nvalue = 12366.127'),
#  Text(0.9467213114754098, 0.0625, 'node #236\nsquared_error = 2348085.202\nsamples = 107\nvalue = 14133.467'),
#  Text(0.9590163934426229, 0.1875, 'node #237\ncut_label <= -1.222\nsquared_error = 3583479.642\nsamples = 83\nvalue = 16180.819'),
#  Text(0.9549180327868853, 0.0625, 'node #238\nsquared_error = 3874718.543\nsamples = 9\nvalue = 13976.111'),
#  Text(0.9631147540983607, 0.0625, 'node #239\nsquared_error = 2884988.688\nsamples = 74\nvalue = 16448.959'),
#  Text(0.9836065573770492, 0.3125, 'node #240\ncarat <= 0.751\nsquared_error = 5252508.423\nsamples = 1348\nvalue = 15409.611'),
#  Text(0.9754098360655737, 0.1875, 'node #241\ntable <= -1.166\nsquared_error = 2756.25\nsamples = 2\nvalue = 2022.5'),
#  Text(0.9713114754098361, 0.0625, 'node #242\nsquared_error = 0.0\nsamples = 1\nvalue = 1970.0'),
#  Text(0.9795081967213115, 0.0625, 'node #243\nsquared_error = 0.0\nsamples = 1\nvalue = 2075.0'),
#  Text(0.9918032786885246, 0.1875, 'node #244\nclarity_label <= -0.194\nsquared_error = 4993620.922\nsamples = 1346\nvalue = 15429.503'),
#  Text(0.9877049180327869, 0.0625, 'node #245\nsquared_error = 5144651.776\nsamples = 1119\nvalue = 15212.643'),
#  Text(0.9959016393442623, 0.0625, 'node #246\nsquared_error = 2874487.51\nsamples = 227\nvalue = 16498.52')]

# %%
##------

# %%
##--TUNE the DecisionTree using GRIDSearchCV for HyperParameter Tuning

# %%
##------CATBoost section -------------
